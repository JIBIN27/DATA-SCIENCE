# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"D:\Users\91773\OneDrive\Desktop\Preprocessing\titanic_dataset.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Passengerid as index column

# %%
data.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### checking basic details of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# ### Fill in all the missing values present in all the columns in the dataset

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1=data[['Age','Cabin','Embarked']]

# %%
data1.isna().sum()
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data1=data1.fillna(method='ffill')

# %%
data1.isnull().sum()
# Out:
# Age         0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data=data.drop(['Age','Cabin','Embarked'],axis=1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
data=pd.concat([data1,data],axis=1)

# %%
data
# Out:
#       Age Cabin Embarked  PassengerId  Survived  Pclass  \
# 0    22.0   C85        S            1         0       3
# 1    38.0   C85        C            2         1       1
# 2    26.0  C123        S            3         1       3
# 3    35.0  C123        S            4         1       1
# 4    35.0   E46        S            5         0       3
# ..    ...   ...      ...          ...       ...     ...
# 886  27.0   B42        S          887         0       2
# 887  19.0   B42        S          888         1       1
# 888  26.0  C148        S          889         0       3
# 889  26.0  C148        C          890         1       1
# 890  32.0  C148        Q          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# ...

# %%
data.set_index('PassengerId')
# Out:
#               Age Cabin Embarked  Survived  Pclass  \
# PassengerId
# 1            22.0   C85        S         0       3
# 2            38.0   C85        C         1       1
# 3            26.0  C123        S         1       3
# 4            35.0  C123        S         1       1
# 5            35.0   E46        S         0       3
# ...           ...   ...      ...       ...     ...
# 887          27.0   B42        S         0       2
# 888          19.0   B42        S         1       1
# 889          26.0  C148        S         0       3
# 890          26.0  C148        C         1       1
# 891          32.0  C148        Q         0       3
#
#                                                           Name     Sex  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1
# 3                                       Heikkinen, Miss. Laina  female      0
# ...

# %%
data.isnull().sum()
# Out:
# Age            0
# Cabin          0
# Embarked       0
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %% [markdown]
# ###  Check and handle outliers in at least 3 columns in the dataset

# %%
data.head()
# Out:
#     Age Cabin Embarked  PassengerId  Survived  Pclass  \
# 0  22.0   C85        S            1         0       3
# 1  38.0   C85        C            2         1       1
# 2  26.0  C123        S            3         1       3
# 3  35.0  C123        S            4         1       1
# 4  35.0   E46        S            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket     Fare
# 0         A/5 21171   7.2500
# 1          PC 17599  71.2833
# 2  STON/O2. 3101282   7.9250
# 3            113803  53.1000
# 4            373450   8.0500

# %% [markdown]
# ### checking any outlier value in Age

# %%
plt.boxplot(data['Age'])
plt.title('Box plot for Age')
plt.show()

# %%
plt.boxplot(data['Age'])
plt.title('Box plot for Age')
plt.show()

# %%
Q1=np.percentile(data['Age'],25)

# %%
Q1
# Out:
# 21.0

# %%
Q2=np.percentile(data['Age'],50)

# %%
Q2
# Out:
# 29.0

# %%
Q3=np.percentile(data['Age'],75)

# %%
Q3
# Out:
# 38.0

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 17.0

# %%
low_lim=Q1-1.5*IQR
upr_lim=Q3+1.5*IQR

# %%
low_lim
# Out:
# -4.5

# %%
upr_lim
# Out:
# 63.5

# %%
outlier=[]
for x in data['Age']:
    if ((x>upr_lim) or (x<low_lim)):
        outlier.append(x)

# %%
outlier
# Out:
# [66.0, 66.0, 66.0, 65.0, 65.0, 64.0, 65.0, 64.0]

# %%
ind=data["Age"]>upr_lim

# %%
data.loc[ind].index
# Out:
# Int64Index([31, 32, 33, 54, 280, 438, 456, 545], dtype='int64')

# %%
data.drop([31, 32, 33, 54, 280, 438, 456, 545],inplace=True)

# %%
data.shape
# Out:
# (874, 12)

# %% [markdown]
# ### Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler(feature_range=(0,1))
x1=min_max.fit_transform(x1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7748\2454356874.py in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 min_max=MinMaxScaler(feature_range=(0,1))
# ----> 3 x1=min_max.fit_transform(x1)
#
# NameError: name 'x1' is not defined
